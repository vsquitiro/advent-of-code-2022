# %%
import os
from collections import defaultdict

cwd = os.getcwd()
file = cwd + '/inputs/input14.txt'

data = open(file).read().splitlines()

rocks = [['.'] * 501]
sand_count = [0]

def draw_horizontal(p1,p2):
  for x in range(p2[0] - p1[0] + 1):
    rocks[p1[1]][p1[0] + x] = '#'

def draw_vertical(p1,p2):
  for y in range(p2[1] - p1[1] + 1):
    rocks[p1[1] + y][p1[0]] = '#'

def build_rocks():
  for line in data:
    points = line.split(' -> ')
    for i in range(len(points)):
      points[i] = points[i].split(',')
      points[i][0] = int(points[i][0])
      points[i][1] = int(points[i][1])
      if points[i][0] >= len(rocks[0]):
        overflow = points[i][0] - len(rocks[0]) + 1
        for j in range(len(rocks)):
          new_space = ['.'] * overflow
          rocks[j] = rocks[j] + new_space
      if points[i][1] >= len(rocks):
        overflow = points[i][1] - len(rocks) + 1
        for j in range(overflow):
          new_space = ['.'] * len(rocks[0])
          rocks.append(new_space)

    for i in range(len(points) - 1):
      p1 = points[i]
      p2 = points[i + 1]
      if p1[0] != p2[0]:
        if p1[0] > p2[0]:
          draw_horizontal(p2,p1)
        else:
          draw_horizontal(p1,p2)
      elif p1[1] != p2[1]:
        if p1[1] > p2[1]:
          draw_vertical(p2,p1)
        else:
          draw_vertical(p1,p2)

def check_sand(x,y):
  if y+1 == len(rocks):
    return False
  else:
    floor = ['#','0']
    if rocks[y+1][x] not in floor:
      return check_sand(x,y+1)
    elif x == 0:
      return False
    elif rocks[y+1][x-1] not in floor:
      return check_sand(x-1,y+1)
    elif x + 1 >= len(rocks[0]):
      return False
    elif rocks[y+1][x+1] not in floor:
      return check_sand(x+1,y+1)
    else:
      rocks[y][x] = '0'
      sand_count[0] = sand_count[0] + 1
      return True

def sand_rests():
  return check_sand(500,0)

build_rocks()

rocks[0][500] = "+"

sand_falling = True
while sand_falling:
  sand_falling = sand_rests()

for line in rocks:
  print("".join(line))

print(sand_count[0])
# Out:
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................+.........................................................................
# ...

# %%
import os
from collections import defaultdict

cwd = os.getcwd()
file = cwd + '/inputs/input14.txt'

data = open(file).read().splitlines()

rocks = [['.'] * 501]
sand_count = [0]

def draw_horizontal(p1,p2):
  for x in range(p2[0] - p1[0] + 1):
    rocks[p1[1]][p1[0] + x] = '#'

def draw_vertical(p1,p2):
  for y in range(p2[1] - p1[1] + 1):
    rocks[p1[1] + y][p1[0]] = '#'

def build_rocks():
  for line in data:
    points = line.split(' -> ')
    for i in range(len(points)):
      points[i] = points[i].split(',')
      points[i][0] = int(points[i][0])
      points[i][1] = int(points[i][1])
      if points[i][0] >= len(rocks[0]):
        overflow = points[i][0] - len(rocks[0]) + 1
        for j in range(len(rocks)):
          new_space = ['.'] * overflow
          rocks[j] = rocks[j] + new_space
      if points[i][1] >= len(rocks):
        overflow = points[i][1] - len(rocks) + 1
        for j in range(overflow):
          new_space = ['.'] * len(rocks[0])
          rocks.append(new_space)

    for i in range(len(points) - 1):
      p1 = points[i]
      p2 = points[i + 1]
      if p1[0] != p2[0]:
        if p1[0] > p2[0]:
          draw_horizontal(p2,p1)
        else:
          draw_horizontal(p1,p2)
      elif p1[1] != p2[1]:
        if p1[1] > p2[1]:
          draw_vertical(p2,p1)
        else:
          draw_vertical(p1,p2)
  new_space = ['.'] * len(rocks[0])
  rocks.append(new_space)

def check_sand(x,y):
  if y+1 == len(rocks):
    rocks[y][x] = '0'
    sand_count[0] = sand_count[0] + 1
  else:
    floor = ['#','0']
    if rocks[y+1][x] not in floor:
      check_sand(x,y+1)
    elif x == 0:
      print('Ouch, we need to make adjustments')
    elif rocks[y+1][x-1] not in floor:
      check_sand(x-1,y+1)
    elif x + 1 >= len(rocks[0]):
      for i in range(len(rocks)):
        rocks[i] = rocks[i] + ['.']
      check_sand(x+1,y+1)
    elif rocks[y+1][x+1] not in floor:
      return check_sand(x+1,y+1)
    else:
      rocks[y][x] = '0'
      sand_count[0] = sand_count[0] + 1
      return True
  return

def sand_rests():
  check_sand(500,0)
  return rocks[0][500] != '0'

build_rocks()

rocks[0][500] = "+"

sand_falling = True
while sand_falling:
  sand_falling = sand_rests()

for line in rocks:
  print("".join(line))

print(sand_count[0])
# Out:
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................0...............................................................................................................................................................
# ...
